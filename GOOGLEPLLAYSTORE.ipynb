# %%
#EDA
#Profile of data 
#Statical 
#Graphical

import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("googleplaystore.csv")

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
df.sample(2)
# Out:
#                                                 App Category  Rating Reviews  \
# 8783                           Super Dr. Parking 3D   FAMILY     4.0    4518
# 2489  Ovia Fertility Tracker & Ovulation Calculator  MEDICAL     4.8   53747
#
#      Size    Installs  Type Price Content Rating      Genres  \
# 8783  41M  1,000,000+  Free     0       Everyone  Simulation
# 2489  13M  1,000,000+  Free     0       Everyone     Medical
#
#            Last Updated         Current Ver Android Ver
# 8783  December 17, 2017                 3.3  4.1 and up
# 2489      July 27, 2018  Varies with device  4.3 and up

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.describe()#Statical info about numerical data
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.describe(include="all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
#          Type  Price Content Rating Genres    Last Updated  \
# count   10840  10841          10840  10841           10841
# unique      3     93              6    120            1378
# top      Free      0       Everyone  Tools  August 3, 2018
# freq    10039  10040           8714    842             326
# mean      NaN    NaN            NaN    NaN             NaN
# std       NaN    NaN            NaN    NaN             NaN
# min       NaN    NaN            NaN    NaN             NaN
# 25%       NaN    NaN            NaN    NaN             NaN
# 50%       NaN    NaN            NaN    NaN             NaN
# 75%       NaN    NaN            NaN    NaN             NaN
# max       NaN    NaN            NaN    NaN             NaN
#
#                Current Ver Android Ver
# count                10833       10838
# unique                2832          33
# top     Varies with device  4.1 and up
# freq                  1459        2451
# mean                   NaN         NaN
# std                    NaN         NaN
# min                    NaN         NaN
# 25%                    NaN         NaN
# 50%                    NaN         NaN
# 75%                    NaN         NaN
# max                    NaN         NaN

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  str
#  1   Category        10841 non-null  str
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  str
#  4   Size            10841 non-null  str
#  5   Installs        10841 non-null  str
#  6   Type            10840 non-null  str
#  7   Price           10841 non-null  str
#  8   Content Rating  10840 non-null  str
#  9   Genres          10841 non-null  str
#  10  Last Updated    10841 non-null  str
#  11  Current Ver     10833 non-null  str
#  12  Android Ver     10838 non-null  str
# dtypes: float64(1), str(12)
# memory usage: 1.1 MB

# %%
df.duplicated().sum()
# Out:
# np.int64(483)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes# all column data type together
# Out:
# App                   str
# Category              str
# Rating            float64
# Reviews               str
# Size                  str
# Installs              str
# Type                  str
# Price                 str
# Content Rating        str
# Genres                str
# Last Updated          str
# Current Ver           str
# Android Ver           str
# dtype: object

# %%
#one column data type
df['Content Rating'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
#one column data type
df['Reviews'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df["Reviews"]
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10358, dtype: str

# %%
df.Reviews.unique()
# Out:
# <StringArray>
# [   '159',    '967',  '87510', '215644',    '167',    '178',  '36815',
#   '13791',    '121',  '13880',
#  ...
#    '2036',  '56496', '376223',    '785',   '5775',    '885',  '88486',
#     '603',   '1195', '398307']
# Length: 6002, dtype: str

# %%
#It is possible that in review column there might be a value which is a string and hence 
#converting the whole column into object

# %%
"1"
# Out:
# '1'

# %%
df[~df.Reviews.str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df.Reviews
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10358, dtype: str

# %%
df_copy = df.copy()

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10358 rows x 13 columns]

# %%
#reseting the inndex >>after dropping the duplicate value the original index is still there
df_copy.reset_index(drop=True,inplace=True)

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10353     4.5      38                 53M       5,000+  Free     0
# 10354     5.0       4                3.6M         100+  Free     0
# 10355     NaN       3                9.5M       1,000+  Free     0
# 10356     4.5     114  Varies with device       1,000+  Free     0
# 10357     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10353       Everyone                  Education     July 25, 2017
# 10354       Everyone                  Education      July 6, 2018
# 10355       Everyone                    Medical  January 20, 2017
# 10356     Mature 17+          Books & Reference  January 19, 2015
# 10357       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10353                1.48          4.1 and up
# 10354                 1.0          4.1 and up
# 10355                 1.0          2.2 and up
# 10356  Varies with device  Varies with device
# 10357  Varies with device  Varies with device
#
# [10358 rows x 13 columns]

# %%
df_copy[~df_copy.Reviews.str.isnumeric()]
# Out:
#                                           App Category  Rating Reviews  \
# 9990  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#         Size Installs Type     Price Content Rating             Genres  \
# 9990  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#      Last Updated Current Ver Android Ver
# 9990       1.0.19  4.0 and up         NaN

# %%
df_copy = df_copy.drop(df_copy.index[9990])

# %%
df_copy[~df_copy.Reviews.str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df_copy.Reviews
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10353        38
# 10354         4
# 10355         3
# 10356       114
# 10357    398307
# Name: Reviews, Length: 10357, dtype: str

# %%
df_copy['Reviews'] = df_copy['Reviews'].astype(int)

# %%
df_copy.Reviews.dtype
# Out:
# dtype('int64')

# %%
df_copy.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10357 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  str
#  1   Category        10357 non-null  str
#  2   Rating          8892 non-null   float64
#  3   Reviews         10357 non-null  int64
#  4   Size            10357 non-null  str
#  5   Installs        10357 non-null  str
#  6   Type            10356 non-null  str
#  7   Price           10357 non-null  str
#  8   Content Rating  10357 non-null  str
#  9   Genres          10357 non-null  str
#  10  Last Updated    10357 non-null  str
#  11  Current Ver     10349 non-null  str
#  12  Android Ver     10355 non-null  str
# dtypes: float64(1), int64(1), str(11)
# memory usage: 1.1 MB

# %%
df["Size"].unique()
# Out:
# <StringArray>
# [  '19M',   '14M',  '8.7M',   '25M',  '2.8M',  '5.6M',   '29M',   '33M',
#   '3.1M',   '28M',
#  ...
#   '467k',  '157k',   '44k',  '676k',   '67k',  '552k',  '885k', '1020k',
#   '582k',  '619k']
# Length: 462, dtype: str

# %%
def size_process(item):
    if str(item)[-1]=="M":
        res = float(str(item).replace("M",""))
        res*1024
        return res
    elif str(item)[-1]=="k":
        res = float(str(item).replace("k",""))
        return res
    else:
        return str(np.nan)

# %%
df_copy["Size"] = df_copy["Size"].apply(size_process)

# %%
df_copy["Size"].unique()
# Out:
# array([19.0, 14.0, 8.7, 25.0, 2.8, 5.6, 29.0, 33.0, 3.1, 28.0, 12.0, 20.0,
#        21.0, 37.0, 2.7, 5.5, 17.0, 39.0, 31.0, 4.2, 7.0, 23.0, 6.0, 6.1,
#        4.6, 9.2, 5.2, 11.0, 24.0, 'nan', 9.4, 15.0, 10.0, 1.2, 26.0, 8.0,
#        7.9, 56.0, 57.0, 35.0, 54.0, 201.0, 3.6, 5.7, 8.6, 2.4, 27.0, 2.5,
#        16.0, 3.4, 8.9, 3.9, 2.9, 38.0, 32.0, 5.4, 18.0, 1.1, 2.2, 4.5,
#        9.8, 52.0, 9.0, 6.7, 30.0, 2.6, 7.1, 3.7, 22.0, 7.4, 6.4, 3.2, 8.2,
#        9.9, 4.9, 9.5, 5.0, 5.9, 13.0, 73.0, 6.8, 3.5, 4.0, 2.3, 7.2, 2.1,
#        42.0, 7.3, 9.1, 55.0, 6.5, 1.5, 7.5, 51.0, 41.0, 48.0, 8.5, 46.0,
#        8.3, 4.3, 4.7, 3.3, 40.0, 7.8, 8.8, 6.6, 5.1, 61.0, 66.0, 79.0,
#        8.4, 118.0, 44.0, 695.0, 1.6, 6.2, 53.0, 1.4, 3.0, 5.8, 3.8, 9.6,
#        45.0, 63.0, 49.0, 77.0, 4.4, 4.8, 70.0, 6.9, 9.3, 8.1, 36.0, 84.0,
#        97.0, 2.0, 1.9, 1.8, 5.3, 47.0, 556.0, 526.0, 76.0, 7.6, 59.0, 9.7,
#        78.0, 72.0, 43.0, 7.7, 6.3, 334.0, 34.0, 93.0, 65.0, 100.0, 58.0,
#        50.0, 68.0, 64.0, 67.0, 60.0, 94.0, 232.0, 99.0, 624.0, 95.0,
#        292.0, 80.0, 1.7, 74.0, 62.0, 69.0, 75.0, 98.0, 85.0, 82.0, 96.0,
#        87.0, 71.0, 86.0, 91.0, 81.0, 92.0, 83.0, 88.0, 704.0, 862.0,
#        899.0, 378.0, 266.0, 375.0, 1.3, 975.0, 980.0, 4.1, 89.0, 696.0,
#        544.0, 525.0, 920.0, 779.0, 853.0, 720.0, 713.0, 772.0, 318.0,
#        241.0, 196.0, 857.0, 953.0, 865.0, 251.0, 930.0, 540.0, 313.0,
#        746.0, 203.0, 314.0, 239.0, 371.0, 220.0, 730.0, 756.0, 293.0,
#        317.0, 924.0, 902.0, 818.0, 939.0, 169.0, 475.0, 965.0, 90.0,
#        545.0, 283.0, 655.0, 714.0, 872.0, 121.0, 322.0, 1.0, 976.0, 172.0,
#        238.0, 549.0, 206.0, 954.0, 444.0, 717.0, 210.0, 609.0, 308.0,
#        705.0, 306.0, 904.0, 473.0, 175.0, 350.0, 383.0, 454.0, 421.0,
#        812.0, 442.0, 842.0, 417.0, 412.0, 459.0, 478.0, 335.0, 782.0,
#        721.0, 430.0, 429.0, 192.0, 200.0, 460.0, 728.0, 496.0, 816.0,
#        414.0, 506.0, 887.0, 613.0, 243.0, 569.0, 778.0, 683.0, 592.0,
#        319.0, 186.0, 840.0, 647.0, 191.0, 373.0, 437.0, 598.0, 716.0,
#        585.0, 982.0, 222.0, 219.0, 948.0, 323.0, 691.0, 511.0, 951.0,
#        963.0, 554.0, 351.0, 208.0, 913.0, 514.0, 551.0, 103.0, 898.0,
#        743.0, 116.0, 153.0, 209.0, 353.0, 499.0, 173.0, 597.0, 809.0,
#        122.0, 411.0, 400.0, 801.0, 787.0, 237.0, 643.0, 986.0, 516.0,
#        837.0, 780.0, 961.0, 269.0, 498.0, 600.0, 749.0, 642.0, 881.0,
#        656.0, 601.0, 221.0, 228.0, 108.0, 940.0, 176.0, 663.0, 942.0,
#        259.0, 164.0, 458.0, 245.0, 629.0, 288.0, 775.0, 785.0, 636.0,
#        916.0, 994.0, 309.0, 485.0, 914.0, 903.0, 608.0, 500.0, 562.0,
#        847.0, 957.0, 688.0, 811.0, 270.0, 329.0, 523.0, 921.0, 874.0,
#        981.0, 784.0, 280.0, 518.0, 754.0, 892.0, 154.0, 860.0, 364.0,
#        387.0, 626.0, 161.0, 879.0, 970.0, 170.0, 141.0, 160.0, 144.0,
#        143.0, 190.0, 376.0, 193.0, 246.0, 658.0, 992.0, 253.0, 420.0,
#        404.0, 470.0, 226.0, 240.0, 234.0, 257.0, 861.0, 467.0, 157.0,
#        676.0, 552.0, 885.0, 1020.0, 582.0, 619.0], dtype=object)

# %%
df_copy["Size"].dtype
# Out:
# dtype('O')

# %%
df_copy.Size = df_copy.Size.astype("float")

# %%
df_copy["Size"].dtype
# Out:
# dtype('float64')

# %%
df_copy.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10357 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  str
#  1   Category        10357 non-null  str
#  2   Rating          8892 non-null   float64
#  3   Reviews         10357 non-null  int64
#  4   Size            8831 non-null   float64
#  5   Installs        10357 non-null  str
#  6   Type            10356 non-null  str
#  7   Price           10357 non-null  str
#  8   Content Rating  10357 non-null  str
#  9   Genres          10357 non-null  str
#  10  Last Updated    10357 non-null  str
#  11  Current Ver     10349 non-null  str
#  12  Android Ver     10355 non-null  str
# dtypes: float64(2), int64(1), str(10)
# memory usage: 1.1 MB

# %%
df_copy["Installs"]
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10353         5,000+
# 10354           100+
# 10355         1,000+
# 10356         1,000+
# 10357    10,000,000+
# Name: Installs, Length: 10357, dtype: str

# %%
df_copy["Installs"] = df_copy["Installs"].str.replace("+","").str.replace(",","")

# %%
#df_copy["Installs"].astype("int")

# %%
df_copy.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10357 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  str
#  1   Category        10357 non-null  str
#  2   Rating          8892 non-null   float64
#  3   Reviews         10357 non-null  int64
#  4   Size            8831 non-null   float64
#  5   Installs        10357 non-null  str
#  6   Type            10356 non-null  str
#  7   Price           10357 non-null  str
#  8   Content Rating  10357 non-null  str
#  9   Genres          10357 non-null  str
#  10  Last Updated    10357 non-null  str
#  11  Current Ver     10349 non-null  str
#  12  Android Ver     10355 non-null  str
# dtypes: float64(2), int64(1), str(10)
# memory usage: 1.1 MB

# %%
df_copy.Price.unique()
# Out:
# <StringArray>
# [      '0',   '$4.99',   '$3.99',   '$6.99',   '$1.49',   '$2.99',   '$7.99',
#    '$5.99',   '$3.49',   '$1.99',   '$9.99',   '$7.49',   '$0.99',   '$9.00',
#    '$5.49',  '$10.00',  '$24.99',  '$11.99',  '$79.99',  '$16.99',  '$14.99',
#    '$1.00',  '$29.99',  '$12.99',   '$2.49',  '$10.99',   '$1.50',  '$19.99',
#   '$15.99',  '$33.99',  '$74.99',  '$39.99',   '$3.95',   '$4.49',   '$1.70',
#    '$8.99',   '$2.00',   '$3.88',  '$25.99', '$399.99',  '$17.99', '$400.00',
#    '$3.02',   '$1.76',   '$4.84',   '$4.77',   '$1.61',   '$2.50',   '$1.59',
#    '$6.49',   '$1.29',   '$5.00',  '$13.99', '$299.99', '$379.99',  '$37.99',
#   '$18.99', '$389.99',  '$19.90',   '$8.49',   '$1.75',  '$14.00',   '$4.85',
#   '$46.99', '$109.99', '$154.99',   '$3.08',   '$2.59',   '$4.80',   '$1.96',
#   '$19.40',   '$3.90',   '$4.59',  '$15.46',   '$3.04',   '$4.29',   '$2.60',
#    '$3.28',   '$4.60',  '$28.99',   '$2.95',   '$2.90',   '$1.97', '$200.00',
#   '$89.99',   '$2.56',  '$30.99',   '$3.61', '$394.99',   '$1.26',   '$1.20',
#    '$1.04']
# Length: 92, dtype: str

# %%
char_to_remove = ["$",",","+"]
cols_to_remove = ["Installs", "Price"]

for char in  char_to_remove:
    for cols in cols_to_remove:
        df_copy[cols] = df_copy[cols].str.replace(char,"")

# %%
df_copy.Price.unique()
# Out:
# <StringArray>
# [     '0',   '4.99',   '3.99',   '6.99',   '1.49',   '2.99',   '7.99',
#    '5.99',   '3.49',   '1.99',   '9.99',   '7.49',   '0.99',   '9.00',
#    '5.49',  '10.00',  '24.99',  '11.99',  '79.99',  '16.99',  '14.99',
#    '1.00',  '29.99',  '12.99',   '2.49',  '10.99',   '1.50',  '19.99',
#   '15.99',  '33.99',  '74.99',  '39.99',   '3.95',   '4.49',   '1.70',
#    '8.99',   '2.00',   '3.88',  '25.99', '399.99',  '17.99', '400.00',
#    '3.02',   '1.76',   '4.84',   '4.77',   '1.61',   '2.50',   '1.59',
#    '6.49',   '1.29',   '5.00',  '13.99', '299.99', '379.99',  '37.99',
#   '18.99', '389.99',  '19.90',   '8.49',   '1.75',  '14.00',   '4.85',
#   '46.99', '109.99', '154.99',   '3.08',   '2.59',   '4.80',   '1.96',
#   '19.40',   '3.90',   '4.59',  '15.46',   '3.04',   '4.29',   '2.60',
#    '3.28',   '4.60',  '28.99',   '2.95',   '2.90',   '1.97', '200.00',
#   '89.99',   '2.56',  '30.99',   '3.61', '394.99',   '1.26',   '1.20',
#    '1.04']
# Length: 92, dtype: str

# %%
df_copy["Installs"]=df_copy["Installs"].astype("int")

# %%
df_copy["Price"] =  df_copy["Price"].astype("float")

# %%
df_copy.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10357 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  str
#  1   Category        10357 non-null  str
#  2   Rating          8892 non-null   float64
#  3   Reviews         10357 non-null  int64
#  4   Size            8831 non-null   float64
#  5   Installs        10357 non-null  int64
#  6   Type            10356 non-null  str
#  7   Price           10357 non-null  float64
#  8   Content Rating  10357 non-null  str
#  9   Genres          10357 non-null  str
#  10  Last Updated    10357 non-null  str
#  11  Current Ver     10349 non-null  str
#  12  Android Ver     10355 non-null  str
# dtypes: float64(3), int64(2), str(8)
# memory usage: 1.1 MB

# %%
df_copy["Last Updated"]
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10353       July 25, 2017
# 10354        July 6, 2018
# 10355    January 20, 2017
# 10356    January 19, 2015
# 10357       July 25, 2018
# Name: Last Updated, Length: 10357, dtype: str

# %%
df_copy["Last Updated"] = pd.to_datetime(df_copy["Last Updated"])

# %%
df_copy["Last Updated"]
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10353   2017-07-25
# 10354   2018-07-06
# 10355   2017-01-20
# 10356   2015-01-19
# 10357   2018-07-25
# Name: Last Updated, Length: 10357, dtype: datetime64[us]

# %%
df_copy["Day"] = df_copy["Last Updated"].dt.day
df_copy["Month"] = df_copy["Last Updated"].dt.month
df_copy["Year"] = df_copy["Last Updated"].dt.year

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews  Size  Installs  Type  Price Content Rating  \
# 0         4.1      159  19.0     10000  Free    0.0       Everyone
# 1         3.9      967  14.0    500000  Free    0.0       Everyone
# 2         4.7    87510   8.7   5000000  Free    0.0       Everyone
# 3         4.5   215644  25.0  50000000  Free    0.0           Teen
# 4         4.3      967   2.8    100000  Free    0.0       Everyone
# ...       ...      ...   ...       ...   ...    ...            ...
# 10353     4.5       38  53.0      5000  Free    0.0       Everyone
# 10354     5.0        4   3.6       100  Free    0.0       Everyone
# 10355     NaN        3   9.5      1000  Free    0.0       Everyone
# 10356     4.5      114   NaN      1000  Free    0.0     Mature 17+
# 10357     4.5   398307  19.0  10000000  Free    0.0       Everyone
#
#                           Genres Last Updated         Current Ver  \
# 0                   Art & Design   2018-01-07               1.0.0
# 1      Art & Design;Pretend Play   2018-01-15               2.0.0
# 2                   Art & Design   2018-08-01               1.2.4
# 3                   Art & Design   2018-06-08  Varies with device
# 4        Art & Design;Creativity   2018-06-20                 1.1
# ...                          ...          ...                 ...
# 10353                  Education   2017-07-25                1.48
# 10354                  Education   2018-07-06                 1.0
# 10355                    Medical   2017-01-20                 1.0
# 10356          Books & Reference   2015-01-19  Varies with device
# 10357                  Lifestyle   2018-07-25  Varies with device
#
#               Android Ver  Day  Month  Year
# 0            4.0.3 and up    7      1  2018
# 1            4.0.3 and up   15      1  2018
# 2            4.0.3 and up    1      8  2018
# 3              4.2 and up    8      6  2018
# 4              4.4 and up   20      6  2018
# ...                   ...  ...    ...   ...
# 10353          4.1 and up   25      7  2017
# 10354          4.1 and up    6      7  2018
# 10355          2.2 and up   20      1  2017
# 10356  Varies with device   19      1  2015
# 10357  Varies with device   25      7  2018
#
# [10357 rows x 16 columns]

# %%
df_copy.dtypes
# Out:
# App                          str
# Category                     str
# Rating                   float64
# Reviews                    int64
# Size                     float64
# Installs                   int64
# Type                         str
# Price                    float64
# Content Rating               str
# Genres                       str
# Last Updated      datetime64[us]
# Current Ver                  str
# Android Ver                  str
# Day                        int32
# Month                      int32
# Year                       int32
# dtype: object

# %%
df_copy.drop("Last Updated" , axis = 1  , inplace = True)

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews  Size  Installs  Type  Price Content Rating  \
# 0         4.1      159  19.0     10000  Free    0.0       Everyone
# 1         3.9      967  14.0    500000  Free    0.0       Everyone
# 2         4.7    87510   8.7   5000000  Free    0.0       Everyone
# 3         4.5   215644  25.0  50000000  Free    0.0           Teen
# 4         4.3      967   2.8    100000  Free    0.0       Everyone
# ...       ...      ...   ...       ...   ...    ...            ...
# 10353     4.5       38  53.0      5000  Free    0.0       Everyone
# 10354     5.0        4   3.6       100  Free    0.0       Everyone
# 10355     NaN        3   9.5      1000  Free    0.0       Everyone
# 10356     4.5      114   NaN      1000  Free    0.0     Mature 17+
# 10357     4.5   398307  19.0  10000000  Free    0.0       Everyone
#
#                           Genres         Current Ver         Android Ver  Day  \
# 0                   Art & Design               1.0.0        4.0.3 and up    7
# 1      Art & Design;Pretend Play               2.0.0        4.0.3 and up   15
# 2                   Art & Design               1.2.4        4.0.3 and up    1
# 3                   Art & Design  Varies with device          4.2 and up    8
# 4        Art & Design;Creativity                 1.1          4.4 and up   20
# ...                          ...                 ...                 ...  ...
# 10353                  Education                1.48          4.1 and up   25
# 10354                  Education                 1.0          4.1 and up    6
# 10355                    Medical                 1.0          2.2 and up   20
# 10356          Books & Reference  Varies with device  Varies with device   19
# 10357                  Lifestyle  Varies with device  Varies with device   25
#
#        Month  Year
# 0          1  2018
# 1          1  2018
# 2          8  2018
# 3          6  2018
# 4          6  2018
# ...      ...   ...
# 10353      7  2017
# 10354      7  2018
# 10355      1  2017
# 10356      1  2015
# 10357      7  2018
#
# [10357 rows x 15 columns]

# %%
df_copy["Android Ver"].unique()
# Out:
# <StringArray>
# [      '4.0.3 and up',         '4.2 and up',         '4.4 and up',
#          '2.3 and up',         '3.0 and up',         '4.1 and up',
#          '4.0 and up',       '2.3.3 and up', 'Varies with device',
#          '2.2 and up',         '5.0 and up',         '6.0 and up',
#          '1.6 and up',         '1.5 and up',         '2.1 and up',
#          '7.0 and up',         '5.1 and up',         '4.3 and up',
#       '4.0.3 - 7.1.1',         '2.0 and up',         '3.2 and up',
#         '4.4W and up',         '7.1 and up',        '7.0 - 7.1.1',
#          '8.0 and up',          '5.0 - 8.0',         '3.1 and up',
#        '2.0.1 and up',        '4.1 - 7.1.1',                  nan,
#           '5.0 - 6.0',         '1.0 and up',        '2.2 - 7.1.1',
#         '5.0 - 7.1.1']
# Length: 34, dtype: str

# %%
df_copy["Android Ver"] =  df_copy["Android Ver"].str.replace("and up","").str.replace("Varies with device","").str.replace("W","")

# %%
df_copy["Android Ver"].unique()
# Out:
# <StringArray>
# [       '4.0.3 ',          '4.2 ',          '4.4 ',          '2.3 ',
#           '3.0 ',          '4.1 ',          '4.0 ',        '2.3.3 ',
#               '',          '2.2 ',          '5.0 ',          '6.0 ',
#           '1.6 ',          '1.5 ',          '2.1 ',          '7.0 ',
#           '5.1 ',          '4.3 ', '4.0.3 - 7.1.1',          '2.0 ',
#           '3.2 ',          '7.1 ',   '7.0 - 7.1.1',          '8.0 ',
#      '5.0 - 8.0',          '3.1 ',        '2.0.1 ',   '4.1 - 7.1.1',
#              nan,     '5.0 - 6.0',          '1.0 ',   '2.2 - 7.1.1',
#    '5.0 - 7.1.1']
# Length: 33, dtype: str

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Current Ver', 'Android Ver',
#        'Day', 'Month', 'Year'],
#       dtype='str')

# %%
df_copy.App
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10353                                     Sya9a Maroc - FR
# 10354                     Fr. Mike Schmitz Audio Teachings
# 10355                               Parkinson Exercices FR
# 10356                        The SCP Foundation DB fr nn5n
# 10357        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10357, dtype: str

# %%
df_copy[df_copy.duplicated("App")]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Current Ver, Android Ver, Day, Month, Year]
# Index: []

# %%
df_copy = df_copy.drop_duplicates(subset=["App"], keep = "first")

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Current Ver', 'Android Ver',
#        'Day', 'Month', 'Year'],
#       dtype='str')

# %%
#EDA
CATEGORICAL_FEATURE = [feature for feature in df_copy.columns if df_copy[feature].dtypes == 'str']
CATEGORICAL_FEATURE
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Current Ver',
#  'Android Ver']

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Current Ver', 'Android Ver',
#        'Day', 'Month', 'Year'],
#       dtype='str')

# %%
NUMERIC_FEATURE = [feature for feature in df_copy.columns if df_copy[feature].dtypes != 'O']

# %%
NUMERIC_FEATURE
# Out:
# ['App',
#  'Category',
#  'Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Current Ver',
#  'Android Ver',
#  'Day',
#  'Month',
#  'Year']

# %%
df_copy[CATEGORICAL_FEATURE]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Type Content Rating                     Genres         Current Ver  \
# 0      Free       Everyone               Art & Design               1.0.0
# 1      Free       Everyone  Art & Design;Pretend Play               2.0.0
# 2      Free       Everyone               Art & Design               1.2.4
# 3      Free           Teen               Art & Design  Varies with device
# 4      Free       Everyone    Art & Design;Creativity                 1.1
# ...     ...            ...                        ...                 ...
# 10353  Free       Everyone                  Education                1.48
# 10354  Free       Everyone                  Education                 1.0
# 10355  Free       Everyone                    Medical                 1.0
# 10356  Free     Mature 17+          Books & Reference  Varies with device
# 10357  Free       Everyone                  Lifestyle  Varies with device
#
#       Android Ver
# 0          4.0.3
# 1          4.0.3
# 2          4.0.3
# 3            4.2
# 4            4.4
# ...           ...
# 10353        4.1
# 10354        4.1
# 10355        2.2
# 10356
# 10357
#
# [9659 rows x 7 columns]

# %%
#categorical data >>>barchart, piechart , freqpllot
#numeric data >>histogram,distplot,boxplot,line chart ,pairplot, scatter plot

# %%
#categorical feature analysis
df_copy["Type"].value_counts(normalize=True)#normalize  >>0 to 1
# Out:
# Type
# Free    0.921723
# Paid    0.078277
# Name: proportion, dtype: float64

# %%
for col in CATEGORICAL_FEATURE:
    print(f"{col}:{df_copy[col].value_counts(normalize=True)*100}")
# Out:
# App:App
# Photo Editor & Candy Camera & Grid & ScrapBook        0.010353
# Coloring book moana                                   0.010353
# U Launcher Lite – FREE Live Cool Themes, Hide Apps    0.010353
# Sketch - Draw & Paint                                 0.010353
# Pixel Draw - Number Art Coloring Book                 0.010353
#                                                         ...
# Sya9a Maroc - FR                                      0.010353
# Fr. Mike Schmitz Audio Teachings                      0.010353
# Parkinson Exercices FR                                0.010353
# The SCP Foundation DB fr nn5n                         0.010353
# iHoroscope - 2018 Daily Horoscope & Astrology         0.010353
# Name: proportion, Length: 9659, dtype: float64
# Category:Category
# FAMILY                 18.966767
# GAME                    9.928564
# TOOLS                   8.561963
# BUSINESS                4.348276
# MEDICAL                 4.089450
# PERSONALIZATION         3.892743
# PRODUCTIVITY            3.872036
# LIFESTYLE               3.820271
# FINANCE                 3.571798
# SPORTS                  3.364738
# COMMUNICATION           3.261207
# HEALTH_AND_FITNESS      2.981675
# PHOTOGRAPHY             2.909204
# NEWS_AND_MAGAZINES      2.629672
# SOCIAL                  2.474376
# BOOKS_AND_REFERENCE     2.298375
# TRAVEL_AND_LOCAL        2.267315
# SHOPPING                2.091314
# DATING                  1.770370
# VIDEO_PLAYERS           1.687545
# MAPS_AND_NAVIGATION     1.356248
# EDUCATION               1.232012
# FOOD_AND_DRINK          1.159540
# ENTERTAINMENT           1.056010
# AUTO_AND_VEHICLES       0.880008
# LIBRARIES_AND_DEMO      0.869655
# WEATHER                 0.817890
# HOUSE_AND_HOME          0.766125
# ART_AND_DESIGN          0.662594
# EVENTS                  0.662594
# PARENTING               0.621182
# COMICS                  0.579770
# BEAUTY                  0.548711
# Name: proportion, dtype: float64
# Type:Type
# Free    92.172292
# Paid     7.827708
# Name: proportion, dtype: float64
# Content Rating:Content Rating
# Everyone           81.820064
# Teen               10.725748
# Mature 17+          4.068744
# Everyone 10+        3.333678
# Adults only 18+     0.031059
# Unrated             0.020706
# Name: proportion, dtype: float64
# Genres:Genres
# Tools                       8.551610
# Entertainment               5.808055
# Education                   5.280050
# Business                    4.348276
# Medical                     4.089450
#                               ...
# Role Playing;Brain Games    0.010353
# Strategy;Education          0.010353
# Racing;Pretend Play         0.010353
# Communication;Creativity    0.010353
# Strategy;Creativity         0.010353
# Name: proportion, Length: 118, dtype: float64
# Current Ver:Current Ver
# Varies with device    10.931510
# 1.0                    8.278935
# 1.1                    2.694021
# 1.2                    1.823645
# 2.0                    1.543881
#                         ...
# 6.04                   0.010362
# 1.5.447                0.010362
# 1.0.612928             0.010362
# 0.3.4                  0.010362
# 2.0.148.0              0.010362
# Name: proportion, Length: 2817, dtype: float64
# Android Ver:Android Ver
# 4.1              22.802112
# 4.0.3            14.445480
# 4.0              13.306410
#                  10.251631
# 4.4               8.584447
# 2.3               6.378793
# 5.0               5.301854
# 4.2               3.852128
# 2.3.3             2.826965
# 2.2               2.474889
# 3.0               2.392047
# 4.3               2.288495
# 2.1               1.377239
# 1.6               1.201201
# 6.0               0.559180
# 7.0               0.434918
# 3.2               0.372787
# 2.0               0.331366
# 5.1               0.227814
# 1.5               0.207104
# 3.1               0.103552
# 2.0.1             0.072486
# 8.0               0.062131
# 7.1               0.031066
# 4.0.3 - 7.1.1     0.020710
# 5.0 - 8.0         0.020710
# 1.0               0.020710
# 7.0 - 7.1.1       0.010355
# 4.1 - 7.1.1       0.010355
# 5.0 - 6.0         0.010355
# 2.2 - 7.1.1       0.010355
# 5.0 - 7.1.1       0.010355
# Name: proportion, dtype: float64

# %%
df_copy["Android Ver"].value_counts(normalize=True)
# Out:
# Android Ver
# 4.1              0.228021
# 4.0.3            0.144455
# 4.0              0.133064
#                  0.102516
# 4.4              0.085844
# 2.3              0.063788
# 5.0              0.053019
# 4.2              0.038521
# 2.3.3            0.028270
# 2.2              0.024749
# 3.0              0.023920
# 4.3              0.022885
# 2.1              0.013772
# 1.6              0.012012
# 6.0              0.005592
# 7.0              0.004349
# 3.2              0.003728
# 2.0              0.003314
# 5.1              0.002278
# 1.5              0.002071
# 3.1              0.001036
# 2.0.1            0.000725
# 8.0              0.000621
# 7.1              0.000311
# 4.0.3 - 7.1.1    0.000207
# 5.0 - 8.0        0.000207
# 1.0              0.000207
# 7.0 - 7.1.1      0.000104
# 4.1 - 7.1.1      0.000104
# 5.0 - 6.0        0.000104
# 2.2 - 7.1.1      0.000104
# 5.0 - 7.1.1      0.000104
# Name: proportion, dtype: float64

# %%
df_copy["Type"].value_counts(normalize=True)*100
# Out:
# Type
# Free    92.172292
# Paid     7.827708
# Name: proportion, dtype: float64

# %%
sns.countplot(x = df_copy["Type"] )
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
sns.countplot(x = df_copy["Content Rating"] )
# Out:
# <Axes: xlabel='Content Rating', ylabel='count'>

# %%
#numeric feature >>

# %%
sns.distplot(df_copy["Price"], kde = True)
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(df_copy["Rating"], kde = True)
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.kdeplot(df_copy["Rating"])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
plt.figure(figsize=(20,15))
category = ["Type","Content Rating"]
for i in range(0,len(category)):
    plt.subplot(2,2,i+1)
    sns.countplot(x = df[category[i]],palette= "Set3")
    plt.xlabel(category[i])
    plt.xticks(rotation=0)
    plt.tight_layout()

# %%
# which categories is most popular categories in the app
df_copy["Category"].value_counts().plot.pie(y=df["Category"],figsize = (12,12),autopct = "%1.1f")
# Out:
# <Axes: >

# %%
# top 10 popular categoriescat =  
cat = df_copy["Category"].value_counts()[:10]

# %%
category = cat.reset_index()

# %%
category
# Out:
#           Category  count
# 0           FAMILY   1832
# 1             GAME    959
# 2            TOOLS    827
# 3         BUSINESS    420
# 4          MEDICAL    395
# 5  PERSONALIZATION    376
# 6     PRODUCTIVITY    374
# 7        LIFESTYLE    369
# 8          FINANCE    345
# 9           SPORTS    325

# %%
category.columns = ["Groups","count"]

# %%
category
# Out:
#             Groups  count
# 0           FAMILY   1832
# 1             GAME    959
# 2            TOOLS    827
# 3         BUSINESS    420
# 4          MEDICAL    395
# 5  PERSONALIZATION    376
# 6     PRODUCTIVITY    374
# 7        LIFESTYLE    369
# 8          FINANCE    345
# 9           SPORTS    325

# %%
sns.barplot(x = category["Groups"] , y = category["count"])
# Out:
# <Axes: xlabel='Groups', ylabel='count'>

# %%
#which category has highest installetion

# %%
df_copy.groupby
